# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "../Resources/country_vaccinations.csv"
world_vac_df = pd.read_csv(csv_file)
world_vac_df.sample(50)
# Out:
#                    country iso_code        date  total_vaccinations  \
# 281                  China      CHN  2020-12-31           4500000.0
# 261                  Chile      CHL  2021-01-27             67096.0
# 366                Croatia      HRV  2021-01-19             54304.0
# 1340              Portugal      PRT  2020-12-29             16701.0
# 1394               Romania      ROU  2021-01-16            196090.0
# 581                Finland      FIN  2021-01-17                 NaN
# 328             Costa Rica      CRI  2021-01-08              9751.0
# 559                Estonia      EST  2021-01-28             31629.0
# 1892                 Wales      NaN  2020-12-26                 NaN
# 1020             Lithuania      LTU  2021-01-23             67911.0
# 1756                Turkey      TUR  2021-01-25           1302753.0
# 1113                Mexico      MEX  2021-01-08             67468.0
# 1430                Russia      RUS  2021-01-03                 NaN
# ...

# %%
csv_file = "../Resources/us_state_vaccinations.csv"
us_vac_df = pd.read_csv(csv_file)
us_vac_df.sample(50)
# Out:
#             date                        location  total_distributed  \
# 636   2021-01-27                Marshall Islands            13600.0
# 1336  2021-01-14                 Veterans Health           941925.0
# 463   2021-01-15                         Indiana           642425.0
# 515   2021-01-21                          Kansas           312000.0
# 196   2021-01-24                     Connecticut           492850.0
# 63    2021-01-29                  American Samoa            18450.0
# 43    2021-02-01                          Alaska           193150.0
# 1115  2021-01-23                     Puerto Rico           371550.0
# 875   2021-01-13                      New Jersey           654900.0
# 344   2021-02-03                         Georgia          1638700.0
# 864   2021-01-25                   New Hampshire           162950.0
# 1096  2021-01-27                    Pennsylvania          1817925.0
# 947   2021-01-16                  North Carolina                NaN
# ...

# %%
csv_file = "../Resources2/covid_impact_on_airport_traffic.csv"
airport_traffic_df = pd.read_csv(csv_file)
airport_traffic_df.sample(50)
# Out:
#      AggregationMethod        Date  Version  \
# 6121             Daily  2020-12-01      1.0
# 4227             Daily  2020-11-05      1.0
# 2979             Daily  2020-09-25      1.0
# 4311             Daily  2020-08-25      1.0
# 5899             Daily  2020-05-10      1.0
# 2453             Daily  2020-04-07      1.0
# 1930             Daily  2020-03-29      1.0
# 1403             Daily  2020-09-06      1.0
# 7046             Daily  2020-10-19      1.0
# 6150             Daily  2020-10-11      1.0
# 6980             Daily  2020-08-10      1.0
# 6666             Daily  2020-08-02      1.0
# 3923             Daily  2020-11-14      1.0
# 1375             Daily  2020-10-14      1.0
# 4474             Daily  2020-05-09      1.0
# 3626             Daily  2020-11-11      1.0
# 1283             Daily  2020-09-19      1.0
# 6122             Daily  2020-09-29      1.0
# 4550             Daily  2020-04-09      1.0
# 4182             Daily  2020-03-29      1.0
# ...

# %%
csv_file = "../Resources2/archive-2/covid_19_clean_complete.csv"
covid_case_df = pd.read_csv(csv_file)
covid_case_df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
csv_file = "../Resources2/archive-2/full_grouped.csv"
covid_world_df = pd.read_csv(csv_file)
covid_world_df.sample(10)
# Out:
#              Date       Country/Region  Confirmed  Deaths  Recovered  Active  \
# 7535   2020-03-02              Eritrea          0       0          0       0
# 30411  2020-07-02           Mozambique        918       6          0     912
# 31401  2020-07-07               Turkey     207897    5260     185292   17345
# 22292  2020-05-20  Congo (Brazzaville)        420      15        132     273
# 33529  2020-07-19              Estonia       2021      69       1912      40
# 667    2020-01-25             Maldives          0       0          0       0
# 4058   2020-02-12             Paraguay          0       0          0       0
# 28116  2020-06-20                Ghana      13717      85      10074    3558
# 7166   2020-02-29              Finland          3       0          1       2
# 9234   2020-03-11               Guinea          0       0          0       0
#
#        New cases  New deaths  New recovered       WHO Region
# 7535           0           0              0           Africa
# ...
