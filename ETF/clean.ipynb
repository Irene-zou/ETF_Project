# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "../Resources/country_vaccinations.csv"
world_vac_df = pd.read_csv(csv_file)
world_vac_df.sample(5)
# Out:
#           country iso_code        date  total_vaccinations  people_vaccinated  \
# 1076        Malta      MLT  2021-01-10                 NaN                NaN
# 1722  Switzerland      CHE  2021-01-08                 NaN                NaN
# 1711  Switzerland      CHE  2020-12-28                 NaN                NaN
# 906        Israel      ISR  2021-01-20           3100522.0          2383269.0
# 610        France      FRA  2021-01-09             86315.0            86315.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1076                      NaN                     NaN               396.0
# 1722                      NaN                     NaN              3000.0
# 1711                      NaN                     NaN              3000.0
# 906                  717253.0                216309.0            143288.0
# 610                       NaN                 10293.0             12278.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1076                             NaN                            NaN
# 1722                             NaN                            NaN
# 1711                             NaN                            NaN
# 906                            35.82                          27.53
# 610                             0.13                           0.13
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 1076                                  NaN                           897.0
# 1722                                  NaN                           347.0
# 1711                                  NaN                           347.0
# 906                                  8.29                         16554.0
# 610                                   NaN                           181.0
#
#                       vaccines                      source_name  \
# 1076           Pfizer/BioNTech               Ministry of Health
# 1722  Moderna, Pfizer/BioNTech  Federal Office of Public Health
# 1711  Moderna, Pfizer/BioNTech  Federal Office of Public Health
# 906   Moderna, Pfizer/BioNTech             Government of Israel
# 610            Pfizer/BioNTech             Public Health France
#
#                                          source_website
# 1076  https://deputyprimeminister.gov.mt/en/health-p...
# 1722  https://www.bag.admin.ch/dam/bag/fr/dokumente/...
# 1711  https://www.bag.admin.ch/dam/bag/fr/dokumente/...
# 906   https://datadashboard.health.gov.il/COVID-19/g...
# 610   https://www.data.gouv.fr/fr/datasets/donnees-r...

# %%
#country,iso_code, date, daily_vaccinations, vaccines,source_name

# %%
csv_file = "../Resources/covid_impact_on_airport_traffic.csv"
airport_traffic_df = pd.read_csv(csv_file)
airport_traffic_df.sample(5)
# Out:
#      AggregationMethod        Date  Version                       AirportName  \
# 2566             Daily   9/19/2020        1                  Montreal Trudeau
# 6777             Daily  10/19/2020        1  Washington Dulles International
# 3375             Daily   10/5/2020        1              Denver International
# 647              Daily    4/4/2020        1             Calgary International
# 121              Daily  10/17/2020        1                   Kingsford Smith
#
#       PercentOfBaseline                                   Centroid     City  \
# 2566                 75  POINT(-73.7424121584688 45.4678436940192)   Dorval
# 6777                 71  POINT(-77.4427728838621 38.9475939204352)   Floris
# 3375                 70  POINT(-104.700315559089 39.8643468206413)   Denver
# 647                  51  POINT(-114.013122872131 51.1184753727795)  Calgary
# 121                  11  POINT(151.180087713813 -33.9459774986125)   Sydney
#
#                 State ISO_3166_2                         Country  \
# 2566           Quebec      CA-QC                          Canada
# 6777         Virginia      US-VA  United States of America (the)
# 3375         Colorado      US-CO  United States of America (the)
# 647           Alberta      CA-AB                          Canada
# 121   New South Wales         AU                       Australia
#
#                                               Geography
# 2566  POLYGON((-73.751757144928 45.44954912446, -73....
# 6777  POLYGON((-77.4458885192871 38.9760921336351, -...
# 3375  POLYGON((-104.661254882812 39.8242265704646, -...
# 647   POLYGON((-113.981866836548 51.1392131913567, -...
# 121   POLYGON((151.164354085922 -33.9301772341877, 1...

# %%
#Date,Country,State,City, AirportName,PercentOfBaseline

# %%
csv_file = "../Resources/covid_19_clean_complete.csv"
covid_case_df = pd.read_csv(csv_file)
covid_case_df.sample(5)
# Out:
#       Province/State Country/Region      Lat      Long        Date  Confirmed  \
# 27858            NaN         Serbia  44.0165   21.0059  2020-05-07       9848
# 387              NaN       Honduras  15.2000  -86.2419  2020-01-23          0
# 47144          Aruba    Netherlands  12.5211  -69.9683  2020-07-20        115
# 17803        Guizhou          China  26.8154  106.8748  2020-03-30        146
# 21632            NaN        Grenada  12.1165  -61.6790  2020-04-13         14
#
#        Deaths  Recovered  Active       WHO Region
# 27858     206       2160    7482           Europe
# 387         0          0       0         Americas
# 47144       3        100      12           Europe
# 17803       2        144       0  Western Pacific
# 21632       0          0      14         Americas

# %%
#change the column:Country/Region to Country
#Date,Country,Confirmed,

# %%
csv_file = "../Resources/worldometer_data.csv"
worldometer_df = pd.read_csv(csv_file)
worldometer_df.sample(5)
# Out:
#     Country/Region Continent  Population  TotalCases  NewCases  TotalDeaths  \
# 129        Iceland    Europe    341465.0        1930       NaN         10.0
# 127  Guinea-Bissau    Africa   1972277.0        2032       NaN         27.0
# 35         Belgium    Europe  11594739.0       71158       NaN       9859.0
# 25      Kazakhstan      Asia  18798667.0       95942       NaN       1058.0
# 124     Mozambique    Africa  31333962.0        2120       NaN         15.0
#
#      NewDeaths  TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# 129        NaN          1825.0           NaN         95.0               NaN
# 127        NaN           944.0           NaN       1061.0               5.0
# 35         NaN         17661.0           NaN      43638.0              61.0
# 25         NaN         68871.0           NaN      26013.0             221.0
# 124        NaN           795.0           NaN       1310.0               NaN
#
#      Tot Cases/1M pop  Deaths/1M pop  TotalTests  Tests/1M pop WHO Region
# 129            5652.0           29.0    149693.0      438385.0     Europe
# 127            1030.0           14.0      1500.0         761.0     Africa
# 35             6137.0          850.0   1767120.0      152407.0     Europe
# 25             5104.0           56.0   2163713.0      115099.0     Europe
# 124              68.0            0.5     65151.0        2079.0     Africa
